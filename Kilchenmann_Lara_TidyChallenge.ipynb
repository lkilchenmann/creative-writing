# %%
import pandas as pd
import json

# %%
literal_path = "/Users/Lara/Downloads/chessbuds_messages.json"

with open(literal_path) as j: 
    chess_dict = json.load(j)

# %%
chess_dict
# Out:
# {'participants': [{'name': 'Scott Pence'},
#   {'name': 'Chad Larson'},
#   {'name': 'Joanna Rusch'},
#   {'name': 'Angela Babbitt Pence'},
#   {'name': 'David Silva'},
#   {'name': 'Aaron Rusch'},
#   {'name': 'Timothy Vanderpool'}],
#  'messages': [{'sender_name': 'Joanna Rusch',
#    'timestamp_ms': 1666374933946,
#    'content': "Maybe he just wants to ride the publicity for a bit longer, even if he doesn't get any money from the lawsuit. Like, I didn't know his name before this but I certainly do now.",
#    'reactions': [{'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'},
#     {'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'}],
#    'type': 'Generic',
#    'is_unsent': False,
#    'is_taken_down': False,
#    'bumped_message_metadata': {'bumped_message': "Maybe he just wants to ride the publicity for a bit longer, even if he doesn't get any money from the lawsuit. Like, I didn't know his name before this but I certainly do now.",
#     'is_bumped': False}},
# ...

# %%
type(chess_dict)
# Out:
# dict

# %%
chess_dict.keys()
# Out:
# dict_keys(['participants', 'messages', 'title', 'is_still_participant', 'thread_type', 'thread_path', 'magic_words', 'joinable_mode'])

# %%
chess_dict["participants"]
# Out:
# [{'name': 'Scott Pence'},
#  {'name': 'Chad Larson'},
#  {'name': 'Joanna Rusch'},
#  {'name': 'Angela Babbitt Pence'},
#  {'name': 'David Silva'},
#  {'name': 'Aaron Rusch'},
#  {'name': 'Timothy Vanderpool'}]

# %%
chess_dict["participants"][2]
# Out:
# {'name': 'Joanna Rusch'}

# %%
type(chess_dict["participants"])
# Out:
# list

# %%
chess_dict["messages"]
# Out:
# [{'sender_name': 'Joanna Rusch',
#   'timestamp_ms': 1666374933946,
#   'content': "Maybe he just wants to ride the publicity for a bit longer, even if he doesn't get any money from the lawsuit. Like, I didn't know his name before this but I certainly do now.",
#   'reactions': [{'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'},
#    {'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'}],
#   'type': 'Generic',
#   'is_unsent': False,
#   'is_taken_down': False,
#   'bumped_message_metadata': {'bumped_message': "Maybe he just wants to ride the publicity for a bit longer, even if he doesn't get any money from the lawsuit. Like, I didn't know his name before this but I certainly do now.",
#    'is_bumped': False}},
#  {'sender_name': 'Chad Larson',
#   'timestamp_ms': 1666373448613,
#   'content': 'To be fair to Hans....no one wants to be associated with an "anal bead" theory.',
#   'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Scott Pence'},
# ...

# %%
type(chess_dict["messages"])
# Out:
# list

# %%
chess_dict.keys()
# Out:
# dict_keys(['participants', 'messages', 'title', 'is_still_participant', 'thread_type', 'thread_path', 'magic_words', 'joinable_mode'])

# %%
chess_dict["thread_path"]
# Out:
# 'inbox/chessbuds_npjakt9u1g'

# %%
(chess_dict["participants"]["messages"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/vn/9q7qrmtd0fgcd7jj5xb9zth80000gn/T/ipykernel_2463/4242283770.py in <module>
# ----> 1 (chess_dict["participants"]["messages"])
#
# TypeError: list indices must be integers or slices, not str

# %%
chess_dict["joinable_mode"]
# Out:
# {'mode': 1, 'link': ''}

# %%
chess_dict["joinable_mode"].keys()
# Out:
# dict_keys(['mode', 'link'])

# %% [markdown]
# I have been trying for a while and can't figure out how to make the dataframe because in class the types were dictionnaries and the types here are more lists. I looked it up and found help on this website: https://stackoverflow.com/questions/30522724/take-multiple-lists-into-dataframe

# %%
message_list = pd.DataFrame(
    ['participants': ["participants"],
     'messages': ["messages"]])
# Out:
#   File "/var/folders/vn/9q7qrmtd0fgcd7jj5xb9zth80000gn/T/ipykernel_2463/2562691565.py", line 2
#     ['participants': ["participants"],
#                    ^
# SyntaxError: invalid syntax

# %%
type(chess_dict["messages"])
# Out:
# list

# %%
chess_dict["messages"]
# Out:
# [{'sender_name': 'Joanna Rusch',
#   'timestamp_ms': 1666374933946,
#   'content': "Maybe he just wants to ride the publicity for a bit longer, even if he doesn't get any money from the lawsuit. Like, I didn't know his name before this but I certainly do now.",
#   'reactions': [{'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'},
#    {'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'}],
#   'type': 'Generic',
#   'is_unsent': False,
#   'is_taken_down': False,
#   'bumped_message_metadata': {'bumped_message': "Maybe he just wants to ride the publicity for a bit longer, even if he doesn't get any money from the lawsuit. Like, I didn't know his name before this but I certainly do now.",
#    'is_bumped': False}},
#  {'sender_name': 'Chad Larson',
#   'timestamp_ms': 1666373448613,
#   'content': 'To be fair to Hans....no one wants to be associated with an "anal bead" theory.',
#   'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Scott Pence'},
# ...

# %%
chess_dict["sender_name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/vn/9q7qrmtd0fgcd7jj5xb9zth80000gn/T/ipykernel_2463/2914910216.py in <module>
# ----> 1 chess_dict["sender_name"]
#
# KeyError: 'sender_name'

# %%
message_list = pd.DataFrame(
    ['participants': ["participants"],
     'messages': ["messages"]])
# Out:
#   File "/var/folders/vn/9q7qrmtd0fgcd7jj5xb9zth80000gn/T/ipykernel_2463/2562691565.py", line 2
#     ['participants': ["participants"],
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# I couldn't figure it out and asked chatGPT for help with my error earlier. I am still valuable because I am doing the entire thinking and how to order it, I just needed help accessing it the way i want it to.

# %%
first_message = chess_dict["messages"][0]

# %%
first_message
# Out:
# {'sender_name': 'Joanna Rusch',
#  'timestamp_ms': 1666374933946,
#  'content': "Maybe he just wants to ride the publicity for a bit longer, even if he doesn't get any money from the lawsuit. Like, I didn't know his name before this but I certainly do now.",
#  'reactions': [{'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'},
#   {'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'}],
#  'type': 'Generic',
#  'is_unsent': False,
#  'is_taken_down': False,
#  'bumped_message_metadata': {'bumped_message': "Maybe he just wants to ride the publicity for a bit longer, even if he doesn't get any money from the lawsuit. Like, I didn't know his name before this but I certainly do now.",
#   'is_bumped': False}}

# %%
print(first_message["content"])
# Out:
# Maybe he just wants to ride the publicity for a bit longer, even if he doesn't get any money from the lawsuit. Like, I didn't know his name before this but I certainly do now.

# %%
all_messages = chess_dict["messages"]

# %%
all_messages
# Out:
# [{'sender_name': 'Joanna Rusch',
#   'timestamp_ms': 1666374933946,
#   'content': "Maybe he just wants to ride the publicity for a bit longer, even if he doesn't get any money from the lawsuit. Like, I didn't know his name before this but I certainly do now.",
#   'reactions': [{'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'},
#    {'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'}],
#   'type': 'Generic',
#   'is_unsent': False,
#   'is_taken_down': False,
#   'bumped_message_metadata': {'bumped_message': "Maybe he just wants to ride the publicity for a bit longer, even if he doesn't get any money from the lawsuit. Like, I didn't know his name before this but I certainly do now.",
#    'is_bumped': False}},
#  {'sender_name': 'Chad Larson',
#   'timestamp_ms': 1666373448613,
#   'content': 'To be fair to Hans....no one wants to be associated with an "anal bead" theory.',
#   'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Scott Pence'},
# ...

# %% [markdown]
# I feel like it is not working like in the class because I am thinking about it wrong or am going down the wrong route but this is the only thing I can think of (with help from chat GPT):

# %%
senders = []
timestamps = []
contents = []
typelist = []
unsent = []
takendown = []
bumped = []
reactions = []

# %%
for message in all_messages:
    senders.append(message.get("sender_name", ""))
    timestamps.append(message.get("timestamp_ms", None))
    contents.append(message.get("content", ""))
    typelist.append(message.get("type", ""))
    unsent.append(message.get("is_unsent", ""))
    takendown.append(message.get("is_taken_down", ""))
    bumped.append(message.get("bumped_message_metadata", ""))
    reactions.append(message.get("reactions", None))

# %%
chessmess_df = pd.DataFrame({
    "Sender": senders,
    "Timestamp": timestamps,
    "Content": contents,
    "Type": typelist,
    "Unsent": unsent,
    "Removed": takendown,
    "Bumped": bumped,
    "Reactions": reactions
})

# %%
chessmess_df
# Out:
#            Sender      Timestamp  \
# 0    Joanna Rusch  1666374933946
# 1     Chad Larson  1666373448613
# 2     Chad Larson  1666373216381
# 3     Scott Pence  1666373164883
# 4     Chad Larson  1666373111157
# ..            ...            ...
# 218   Scott Pence  1615855643693
# 219   Scott Pence  1615855620614
# 220   Chad Larson  1615854725212
# 221   Chad Larson  1615854680797
# 222   Chad Larson  1615854650355
#
#                                                Content       Type  Unsent  \
# 0    Maybe he just wants to ride the publicity for ...    Generic   False
# 1    To be fair to Hans....no one wants to be assoc...    Generic   False
# 2    He would have to prove he didn't cheat and tha...    Generic   False
# 3    Yeah, no way. You over shoot and hope to get a...    Generic   False
# 4    From what I see, I don't think he could win.  ...    Generic   False
# ..                                                 ...        ...     ...
# ...

# %% [markdown]
# The code in the cell below i learned from chatgpt as well.

# %%
# Convert timestamps from milliseconds to datetime
chessmess_df["Timestamp"] = pd.to_datetime(chessmess_df["Timestamp"], unit='ms')

# %%
chessmess_df
# Out:
#            Sender               Timestamp  \
# 0    Joanna Rusch 2022-10-21 17:55:33.946
# 1     Chad Larson 2022-10-21 17:30:48.613
# 2     Chad Larson 2022-10-21 17:26:56.381
# 3     Scott Pence 2022-10-21 17:26:04.883
# 4     Chad Larson 2022-10-21 17:25:11.157
# ..            ...                     ...
# 218   Scott Pence 2021-03-16 00:47:23.693
# 219   Scott Pence 2021-03-16 00:47:00.614
# 220   Chad Larson 2021-03-16 00:32:05.212
# 221   Chad Larson 2021-03-16 00:31:20.797
# 222   Chad Larson 2021-03-16 00:30:50.355
#
#                                                Content       Type  Unsent  \
# 0    Maybe he just wants to ride the publicity for ...    Generic   False
# 1    To be fair to Hans....no one wants to be assoc...    Generic   False
# 2    He would have to prove he didn't cheat and tha...    Generic   False
# 3    Yeah, no way. You over shoot and hope to get a...    Generic   False
# 4    From what I see, I don't think he could win.  ...    Generic   False
# ...

# %% [markdown]
# Personally I think this already works pretty well. I am worried that I got rid of most columns just because these seemed the most interesting to me... I will go back over it and try to add the others (I am not using chatGPT anymore, I just needed it to get to any sort of list format)

# %% [markdown]
# Okay, now everything is confusing because when you read it it works from the first time but I went back over it a couple of times so this is where I got without help after I had help to get a list:

# %%
chessmess_df
# Out:
#            Sender               Timestamp  \
# 0    Joanna Rusch 2022-10-21 17:55:33.946
# 1     Chad Larson 2022-10-21 17:30:48.613
# 2     Chad Larson 2022-10-21 17:26:56.381
# 3     Scott Pence 2022-10-21 17:26:04.883
# 4     Chad Larson 2022-10-21 17:25:11.157
# ..            ...                     ...
# 218   Scott Pence 2021-03-16 00:47:23.693
# 219   Scott Pence 2021-03-16 00:47:00.614
# 220   Chad Larson 2021-03-16 00:32:05.212
# 221   Chad Larson 2021-03-16 00:31:20.797
# 222   Chad Larson 2021-03-16 00:30:50.355
#
#                                                Content       Type  Unsent  \
# 0    Maybe he just wants to ride the publicity for ...    Generic   False
# 1    To be fair to Hans....no one wants to be assoc...    Generic   False
# 2    He would have to prove he didn't cheat and tha...    Generic   False
# 3    Yeah, no way. You over shoot and hope to get a...    Generic   False
# 4    From what I see, I don't think he could win.  ...    Generic   False
# ...

# %% [markdown]
# The issue for me right now is that bunmped and reactions looks terrible. I like that I got "None" there but I don't even know what these reactions are and how to go about it.

# %%
chessmess_df["Bumped"].iloc[0]
# Out:
# {'bumped_message': "Maybe he just wants to ride the publicity for a bit longer, even if he doesn't get any money from the lawsuit. Like, I didn't know his name before this but I certainly do now.",
#  'is_bumped': False}

# %% [markdown]
# I dont even know what bumping a message means... I am making an executive decision to cut it.

# %%
chessmess_df.drop(columns = ["Bumped"])
# Out:
#            Sender               Timestamp  \
# 0    Joanna Rusch 2022-10-21 17:55:33.946
# 1     Chad Larson 2022-10-21 17:30:48.613
# 2     Chad Larson 2022-10-21 17:26:56.381
# 3     Scott Pence 2022-10-21 17:26:04.883
# 4     Chad Larson 2022-10-21 17:25:11.157
# ..            ...                     ...
# 218   Scott Pence 2021-03-16 00:47:23.693
# 219   Scott Pence 2021-03-16 00:47:00.614
# 220   Chad Larson 2021-03-16 00:32:05.212
# 221   Chad Larson 2021-03-16 00:31:20.797
# 222   Chad Larson 2021-03-16 00:30:50.355
#
#                                                Content       Type  Unsent  \
# 0    Maybe he just wants to ride the publicity for ...    Generic   False
# 1    To be fair to Hans....no one wants to be assoc...    Generic   False
# 2    He would have to prove he didn't cheat and tha...    Generic   False
# 3    Yeah, no way. You over shoot and hope to get a...    Generic   False
# 4    From what I see, I don't think he could win.  ...    Generic   False
# ...

# %%
chessmess_df["Reactions"].iloc[0]
# Out:
# [{'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'},
#  {'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'}]

# %%
type(chessmess_df["Reactions"])
# Out:
# pandas.core.series.Series

# %%
Reactions_trial = [x for x in chessmess_df["Reactions"]]

# %%
Reactions_trial
# Out:
# [[{'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'},
#   {'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'}],
#  [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Scott Pence'},
#   {'reaction': 'ð\x9f\x98\x86', 'actor': 'Scott Pence'}],
#  [{'reaction': 'ð\x9f\x91\x8d', 'actor': 'Scott Pence'},
#   {'reaction': 'ð\x9f\x91\x8d', 'actor': 'Scott Pence'}],
#  [{'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'},
#   {'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'}],
#  None,
#  [{'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'},
#   {'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'}],
#  [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Joanna Rusch'},
#   {'reaction': 'ð\x9f\x98\x86', 'actor': 'Joanna Rusch'}],
#  None,
#  [{'reaction': 'ð\x9f\x98\x83', 'actor': 'Chad Larson'},
#   {'reaction': 'â\x9d¤', 'actor': 'Joanna Rusch'},
#   {'reaction': 'ð\x9f\x98\x83', 'actor': 'Chad Larson'},
#   {'reaction': 'â\x9d¤', 'actor': 'Joanna Rusch'}],
# ...

# %%
type(Reactions_trial)
# Out:
# list

# %%
Reactions_trial = [x["reaction"] for x in chessmess_df["Reactions"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/vn/9q7qrmtd0fgcd7jj5xb9zth80000gn/T/ipykernel_2463/1362935465.py in <module>
# ----> 1 Reactions_trial = [x["reaction"] for x in chessmess_df["Reactions"]]
#
# /var/folders/vn/9q7qrmtd0fgcd7jj5xb9zth80000gn/T/ipykernel_2463/1362935465.py in <listcomp>(.0)
# ----> 1 Reactions_trial = [x["reaction"] for x in chessmess_df["Reactions"]]
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# I don't understand why this isn't working like in class.

# %%
chessmess_df
# Out:
#            Sender               Timestamp  \
# 0    Joanna Rusch 2022-10-21 17:55:33.946
# 1     Chad Larson 2022-10-21 17:30:48.613
# 2     Chad Larson 2022-10-21 17:26:56.381
# 3     Scott Pence 2022-10-21 17:26:04.883
# 4     Chad Larson 2022-10-21 17:25:11.157
# ..            ...                     ...
# 218   Scott Pence 2021-03-16 00:47:23.693
# 219   Scott Pence 2021-03-16 00:47:00.614
# 220   Chad Larson 2021-03-16 00:32:05.212
# 221   Chad Larson 2021-03-16 00:31:20.797
# 222   Chad Larson 2021-03-16 00:30:50.355
#
#                                                Content       Type  Unsent  \
# 0    Maybe he just wants to ride the publicity for ...    Generic   False
# 1    To be fair to Hans....no one wants to be assoc...    Generic   False
# 2    He would have to prove he didn't cheat and tha...    Generic   False
# 3    Yeah, no way. You over shoot and hope to get a...    Generic   False
# 4    From what I see, I don't think he could win.  ...    Generic   False
# ...

# %% [markdown]
# Why is bumped back?

# %% [markdown]
# I am doing another re-run

# %%
chessmess_df
# Out:
#            Sender               Timestamp  \
# 0    Joanna Rusch 2022-10-21 17:55:33.946
# 1     Chad Larson 2022-10-21 17:30:48.613
# 2     Chad Larson 2022-10-21 17:26:56.381
# 3     Scott Pence 2022-10-21 17:26:04.883
# 4     Chad Larson 2022-10-21 17:25:11.157
# ..            ...                     ...
# 218   Scott Pence 2021-03-16 00:47:23.693
# 219   Scott Pence 2021-03-16 00:47:00.614
# 220   Chad Larson 2021-03-16 00:32:05.212
# 221   Chad Larson 2021-03-16 00:31:20.797
# 222   Chad Larson 2021-03-16 00:30:50.355
#
#                                                Content       Type  Unsent  \
# 0    Maybe he just wants to ride the publicity for ...    Generic   False
# 1    To be fair to Hans....no one wants to be assoc...    Generic   False
# 2    He would have to prove he didn't cheat and tha...    Generic   False
# 3    Yeah, no way. You over shoot and hope to get a...    Generic   False
# 4    From what I see, I don't think he could win.  ...    Generic   False
# ...

# %%
chessmess_df.drop(columns = ["Bumped"])
# Out:
#            Sender               Timestamp  \
# 0    Joanna Rusch 2022-10-21 17:55:33.946
# 1     Chad Larson 2022-10-21 17:30:48.613
# 2     Chad Larson 2022-10-21 17:26:56.381
# 3     Scott Pence 2022-10-21 17:26:04.883
# 4     Chad Larson 2022-10-21 17:25:11.157
# ..            ...                     ...
# 218   Scott Pence 2021-03-16 00:47:23.693
# 219   Scott Pence 2021-03-16 00:47:00.614
# 220   Chad Larson 2021-03-16 00:32:05.212
# 221   Chad Larson 2021-03-16 00:31:20.797
# 222   Chad Larson 2021-03-16 00:30:50.355
#
#                                                Content       Type  Unsent  \
# 0    Maybe he just wants to ride the publicity for ...    Generic   False
# 1    To be fair to Hans....no one wants to be assoc...    Generic   False
# 2    He would have to prove he didn't cheat and tha...    Generic   False
# 3    Yeah, no way. You over shoot and hope to get a...    Generic   False
# 4    From what I see, I don't think he could win.  ...    Generic   False
# ...

# %%
chessmess_df["Reactions"]
# Out:
# 0      [{'reaction': 'ð', 'actor': 'Chad Larson'},...
# 1      [{'reaction': 'ð', 'actor': 'Scott Pence'},...
# 2      [{'reaction': 'ð', 'actor': 'Scott Pence'},...
# 3      [{'reaction': 'ð', 'actor': 'Chad Larson'},...
# 4                                                   None
#                              ...
# 218                                                 None
# 219       [{'reaction': 'ð', 'actor': 'Chad Larson'}]
# 220                                                 None
# 221                                                 None
# 222                                                 None
# Name: Reactions, Length: 223, dtype: object

# %%
len(chessmess_df["Reactions"])
# Out:
# 223

# %%
count_reactions = [len(x) for x in chessmess_df["Reactions"]]
count_reactions
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/vn/9q7qrmtd0fgcd7jj5xb9zth80000gn/T/ipykernel_2463/975972870.py in <module>
# ----> 1 count_reactions = [len(x) for x in chessmess_df["Reactions"]]
#       2 count_reactions
#
# /var/folders/vn/9q7qrmtd0fgcd7jj5xb9zth80000gn/T/ipykernel_2463/975972870.py in <listcomp>(.0)
# ----> 1 count_reactions = [len(x) for x in chessmess_df["Reactions"]]
#       2 count_reactions
#
# TypeError: object of type 'NoneType' has no len()

# %%
chessmess_df
# Out:
#            Sender               Timestamp  \
# 0    Joanna Rusch 2022-10-21 17:55:33.946
# 1     Chad Larson 2022-10-21 17:30:48.613
# 2     Chad Larson 2022-10-21 17:26:56.381
# 3     Scott Pence 2022-10-21 17:26:04.883
# 4     Chad Larson 2022-10-21 17:25:11.157
# ..            ...                     ...
# 218   Scott Pence 2021-03-16 00:47:23.693
# 219   Scott Pence 2021-03-16 00:47:00.614
# 220   Chad Larson 2021-03-16 00:32:05.212
# 221   Chad Larson 2021-03-16 00:31:20.797
# 222   Chad Larson 2021-03-16 00:30:50.355
#
#                                                Content       Type  Unsent  \
# 0    Maybe he just wants to ride the publicity for ...    Generic   False
# 1    To be fair to Hans....no one wants to be assoc...    Generic   False
# 2    He would have to prove he didn't cheat and tha...    Generic   False
# 3    Yeah, no way. You over shoot and hope to get a...    Generic   False
# 4    From what I see, I don't think he could win.  ...    Generic   False
# ...

# %%
chessmess_df = chessmess_df.drop(columns = ["Bumped"])

# %%
chessmess_df
# Out:
#            Sender               Timestamp  \
# 0    Joanna Rusch 2022-10-21 17:55:33.946
# 1     Chad Larson 2022-10-21 17:30:48.613
# 2     Chad Larson 2022-10-21 17:26:56.381
# 3     Scott Pence 2022-10-21 17:26:04.883
# 4     Chad Larson 2022-10-21 17:25:11.157
# ..            ...                     ...
# 218   Scott Pence 2021-03-16 00:47:23.693
# 219   Scott Pence 2021-03-16 00:47:00.614
# 220   Chad Larson 2021-03-16 00:32:05.212
# 221   Chad Larson 2021-03-16 00:31:20.797
# 222   Chad Larson 2021-03-16 00:30:50.355
#
#                                                Content       Type  Unsent  \
# 0    Maybe he just wants to ride the publicity for ...    Generic   False
# 1    To be fair to Hans....no one wants to be assoc...    Generic   False
# 2    He would have to prove he didn't cheat and tha...    Generic   False
# 3    Yeah, no way. You over shoot and hope to get a...    Generic   False
# 4    From what I see, I don't think he could win.  ...    Generic   False
# ...

# %%
chessmess_df["Reactions"]
# Out:
# 0      [{'reaction': 'ð', 'actor': 'Chad Larson'},...
# 1      [{'reaction': 'ð', 'actor': 'Scott Pence'},...
# 2      [{'reaction': 'ð', 'actor': 'Scott Pence'},...
# 3      [{'reaction': 'ð', 'actor': 'Chad Larson'},...
# 4                                                   None
#                              ...
# 218                                                 None
# 219       [{'reaction': 'ð', 'actor': 'Chad Larson'}]
# 220                                                 None
# 221                                                 None
# 222                                                 None
# Name: Reactions, Length: 223, dtype: object

# %%
type(chessmess_df["Reactions"])
# Out:
# pandas.core.series.Series

# %%
len(chessmess_df.reactions)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/vn/9q7qrmtd0fgcd7jj5xb9zth80000gn/T/ipykernel_2463/1798266467.py in <module>
# ----> 1 len(chessmess_df.reactions)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'reactions'

# %%
len(chessmess_df["Reactions"])
# Out:
# 223

# %% [markdown]
# I cannot figure out the reactions thing. I've been working on this for close to two hours now. I am very frustrated. I just noticed that my senders list, although chronological, might not meed tidy standards either.

# %% [markdown]
# I do not think it would make sense to change the first row. This is a text conversation. It would be more messy if you cannot follow the text conversation chronologically.

# %% [markdown]
# In a Markdown cell, describe what you have set the row-level (observation) to represent and what you have set each column to represent: The row level represents the sender, which is important in a text conversation. The columns then show... wait what if the content is the row?

# %%
chessmess_pivot = chessmess_meld.pivot(index='Content', columns='Sender', "Timestamp", "Type", "Unsent", "Removed", "Reactions")
print(chessmess_pivot)
# Out:
#   File "/var/folders/vn/9q7qrmtd0fgcd7jj5xb9zth80000gn/T/ipykernel_2463/326514363.py", line 1
#     chessmess_pivot = chessmess_meld.pivot(index='Content', columns='Sender', "Timestamp", "Type", "Unsent", "Removed", "Reactions")
#                                                                                                                                    ^
# SyntaxError: positional argument follows keyword argument

# %%
chessmess_df
# Out:
#            Sender               Timestamp  \
# 0    Joanna Rusch 2022-10-21 17:55:33.946
# 1     Chad Larson 2022-10-21 17:30:48.613
# 2     Chad Larson 2022-10-21 17:26:56.381
# 3     Scott Pence 2022-10-21 17:26:04.883
# 4     Chad Larson 2022-10-21 17:25:11.157
# ..            ...                     ...
# 218   Scott Pence 2021-03-16 00:47:23.693
# 219   Scott Pence 2021-03-16 00:47:00.614
# 220   Chad Larson 2021-03-16 00:32:05.212
# 221   Chad Larson 2021-03-16 00:31:20.797
# 222   Chad Larson 2021-03-16 00:30:50.355
#
#                                                Content       Type  Unsent  \
# 0    Maybe he just wants to ride the publicity for ...    Generic   False
# 1    To be fair to Hans....no one wants to be assoc...    Generic   False
# 2    He would have to prove he didn't cheat and tha...    Generic   False
# 3    Yeah, no way. You over shoot and hope to get a...    Generic   False
# 4    From what I see, I don't think he could win.  ...    Generic   False
# ...

# %%
chessmess_df = chessmess_df[["Content", "Sender", "Timestamp", "Type", "Unsent", "Removed", "Reactions"]]

# %%
chessmess_df
# Out:
#                                                Content        Sender  \
# 0    Maybe he just wants to ride the publicity for ...  Joanna Rusch
# 1    To be fair to Hans....no one wants to be assoc...   Chad Larson
# 2    He would have to prove he didn't cheat and tha...   Chad Larson
# 3    Yeah, no way. You over shoot and hope to get a...   Scott Pence
# 4    From what I see, I don't think he could win.  ...   Chad Larson
# ..                                                 ...           ...
# 218                              Thank you, thank you.   Scott Pence
# 219                                                      Scott Pence
# 220  Chad Larson added Angela Babbitt Pence to the ...   Chad Larson
# 221  Scott studied my games, did a specific opening...   Chad Larson
# 222                   Chad named the group Chess Buds.   Chad Larson
#
#                   Timestamp       Type  Unsent  Removed  \
# 0   2022-10-21 17:55:33.946    Generic   False    False
# ...

# %% [markdown]
# That looks a lot better

# %% [markdown]
# In a Markdown cell, describe what you have set the row-level (observation) to represent and what you have set each column to represent: Row-level is each indiviual message. Columns are content, Sender, Timestamp, Type, Unsent, Removed and Reactions.

# %% [markdown]
# In a Markdown cell, explain why your final DataFrame meets tidy data principles
#
# What are (if any) alternative, tidy formats that would also be acceptable for this data?
#
# Okay, so obviously my daraframe does not meet the tidy data principles in column reactions because there are multiple values in there. However, I could not figure out how to change that and after hours spend I could not afford more hours on it so I am admitting my mistake and try to incorporate this into this answer. Otherwise, it is conforming to the principles because there's only one value in each field,  the head columns are clear and it looks clean. Another alternative could be to split up timestamp into day and hour.

# %% [markdown]
# In a Markdown cell, describe a potential visualization that would let someone explore and, ultimately, better understand this data
#
# Be specific citing the variables available in the data and how the information would be mapped to the visual elements.
#
# I am thinking of a X and Y map. On Y, you got the author of the  message (Sender), on X you got the time-line (in minutes from timestamps). Or the other way around, either works. It could be interactive if when you hover over the point (signifying the message) the content would show up in a pop up infobox. Reactions could also be shown there.

# %% [markdown]
# I am sorry for not being able to solve this. I tried really hard and invested 4 hours into this (from Tuesday until now) and with work and other classes I cannot commit more hours by tonight and there are no office hours on Thursdays.

# %%
chessmess_df["Reactions"].iloc[0]
# Out:
# [{'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'},
#  {'reaction': 'ð\x9f\x91\x8d', 'actor': 'Chad Larson'}]

# %%
type(chessmess_df["Reactions"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# If it were a dictionnary I could probably split it up.

# %%
first_slice = chessmess_df["Reactions"].iloc[:12]

# %%
first_slice
# Out:
# 0     [{'reaction': 'ð', 'actor': 'Chad Larson'},...
# 1     [{'reaction': 'ð', 'actor': 'Scott Pence'},...
# 2     [{'reaction': 'ð', 'actor': 'Scott Pence'},...
# 3     [{'reaction': 'ð', 'actor': 'Chad Larson'},...
# 4                                                  None
# 5     [{'reaction': 'ð', 'actor': 'Chad Larson'},...
# 6     [{'reaction': 'ð', 'actor': 'Joanna Rusch'}...
# 7                                                  None
# 8     [{'reaction': 'ð', 'actor': 'Chad Larson'},...
# 9     [{'reaction': 'ð', 'actor': 'Chad Larson'},...
# 10                                                 None
# 11                                                 None
# Name: Reactions, dtype: object

# %%
len(first_slice)
# Out:
# 12

# %%
count_first_slice = [len(x) for x in [first_slice]]

# %%
count_first_slice
# Out:
# [12]

# %% [markdown]
# I just cannot figure this out. It's been five hours. The answers for the markdown cells are further up there.
